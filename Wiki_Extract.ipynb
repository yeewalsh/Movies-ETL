# %%
import json
import pandas as pd
import numpy as np
import re

# to import to postgreSQL later
from sqlalchemy import create_engine

# %%
file_dir = "C://Users/ellye/Documents/Bootcamp/Analysis Projects/Movies-ETL/Rsources/"

# %%
with open(f'{file_dir}wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
# check the data - is there enough or too much?
len(wiki_movies_raw)
# Out:
# 7311

# %%
# first 5 records
wiki_movies_raw[:5]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
# ...

# %%
# last  5 records
wiki_movies_raw[-5:]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Holmes_%26_Watson',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt1255919/',
#   'title': 'Holmes & Watson',
#   'Directed by': 'Etan Cohen',
#   'Produced by': ['Will Ferrell',
#    'Adam McKay',
#    'Jimmy Miller',
#    'Clayton Townsend'],
#   'Screenplay by': 'Etan Cohen',
#   'Based on': ['Sherlock Holmes',
#    'and',
#    'Dr. Watson',
#    'by',
#    'Sir Arthur Conan Doyle'],
#   'Starring': ['Will Ferrell',
#    'John C. Reilly',
#    'Rebecca Hall',
#    'Rob Brydon',
#    'Steve Coogan',
#    'Ralph Fiennes'],
#   'Music by': 'Mark Mothersbaugh',
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Dean Zimmerman',
#   'Productioncompanies ': ['Columbia Pictures',
#    'Gary Sanchez Productions',
#    'Mosaic Media Group',
#    'Mimran Schur Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': ['December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
# ...

# %%
# some records in the middle 
wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
# ...

# %%
wiki_movies_df = pd.DataFrame(wiki_movies_raw)
wiki_movies_df.head()
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# ...

# %%
sorted(wiki_movies_df.columns.tolist())

# columns that hold alternate titles: "Also known as", "Arabic", "Cantonese", "Chinese", "French", "Gwoyeu Romatzyh", "Hangul",
# "Hanyu Pinyin", "Hepburn", "Hebrew", "Japanese", "Jyutping", "McCune–Reischauer", "Mandarin", "Original title", "Polish", "Revised Romanization", "Romanized", "Russian", "Traditional", 
# "Simplified", "Simplified Chinese", "Yiddish" 
# columns that should be removed: Alias, Bopomofo, "Coordinates", "Dewey Decimal",
# Out:
# ['Actor control',
#  'Adaptation by',
#  'Alias',
#  'Alma mater',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Area',
#  'Area served',
#  'Artist(s)',
#  'Attraction type',
#  'Audio format',
#  'Author',
#  'Based on',
#  'Biographical data',
#  'Bopomofo',
#  'Born',
#  'Box office',
#  'Budget',
#  'Camera setup',
#  'Cantonese',
#  'Characters',
#  'Children',
#  'Chinese',
#  'Cinematography',
#  'Closing date',
#  'Color process',
#  'Comics',
#  'Composer(s)',
#  'Coordinates',
#  'Country',
#  'Country of origin',
#  'Cover artist',
#  'Created by',
#  'Date premiered',
#  'Designer(s)',
#  'Developed by',
#  'Developer(s)',
#  'Dewey Decimal',
#  'Died',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Divisions',
#  'Duration',
#  'Edited by',
#  'Editor(s)',
#  'Ending theme',
#  'Engine',
#  'Engine(s)',
#  'Executive producer(s)',
#  'Family',
#  'Fate',
#  'Film(s)',
#  'Followed by',
#  'Format(s)',
#  'Formerly',
#  'Founded',
# ...

# %%
wiki_movies_df[wiki_movies_df["Hebrew"].notnull()]['url']
# Out:
# 7089    https://en.wikipedia.org/wiki/Foxtrot_(2017_film)
# Name: url, dtype: object

# %%
# filter out movies that only have a Director or Directed By field and an IMDb link.

wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
               and 'imdb_link' in movie
              # filter out tv shows with "No. of episodes"
              and 'No. of episodes' not in movie]
len(wiki_movies)
# Out:
# 7076

# %%
wiki_movies_df[wiki_movies_df['Directed by'].notnull()]
# Out:
#                                                     url    year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
# ...                                                 ...     ...
# 7306    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018.0
# 7307     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018.0
# 7308  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018.0
# 7309  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018.0
# 7310  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018.0
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# ...

# %%
# make a function to clean the movie data

def clean_movie(movie):
    # make a copy of the movie so you don't mess up the original data w/ a dict constructor
    movie = dict(movie) 
    
    # combine the alternate titles into a dictionary and add the data points as it's own column
    alt_titles = {}
    
    # loop through the alterate title keys and check if the value exists
    for key in ["Also known as", "Arabic", "Cantonese", "Chinese", "French", 
                "Gwoyeu Romatzyh", "Hangul", "Hanyu Pinyin", "Hepburn", "Hebrew", "Japanese", 
                "Jyutping", "McCune–Reischauer", "Mandarin", "Original title", 
                "Polish", "Revised Romanization", "Romanized", "Russian", "Traditional", 
                "Simplified", "Simplified Chinese", "Yiddish"]:
        
        if key in movie:
            # remove the key-value pair and add it to the alt_titles dict
            alt_titles[key] = movie[key]
            movie.pop(key)
            
            
    #add the alt_titles dict to the movie ojbect
    if len(alt_titles) > 0:
        movie["alt_titles"] = alt_titles
        
    # create a function to consolidate similar columns
    def change_column_name(old_name, new_name):
        
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Directed by', 'Director')
    change_column_name('Country of origin', 'Country')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Original release', 'Release date')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release date')
    change_column_name('Release', 'Release date')
    change_column_name('Release(s)', 'Release date')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')
    
    
    return movie

# %%
# use list comprehension to clean the wiki_movies and recreate wiki_movies_df
clean_movies = [clean_movie(movie) for movie in wiki_movies]

wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Literally',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Suggested by',
#  'Venue',
#  'Voices of',
#  'Writer(s)',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
# use Regex to pull out the IMDb ID from the imdb_link, check how many you pull and see if there are nulls, then drop duplicates:

wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
print(len(wiki_movies_df))
wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
print(len(wiki_movies_df))
wiki_movies_df.head()
# Out:
# 7076
# 7033
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# ...

# %%
# find mostly unfilled columns and drop them
# [[column,wiki_movies_df[column].isnull().sum()] for column in wiki_movies_df.columns]
# wiki_movies_df.isnull().sum() <-- what I came up with, shows a list of numbers w/ column titles, seems to work!

# tweak list comprehension to check for the good columns we want to keep and store them in a dataframe
wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5948/699408703.py in <module>
#       4
#       5 # tweak list comprehension to check for the good columns we want to keep and store them in a dataframe
# ----> 6 wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
#       7 wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]
#
# NameError: name 'wiki_movies_df' is not defined

# %%
wiki_movies_df.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5948/3262658768.py in <module>
# ----> 1 wiki_movies_df.columns.tolist()
#
# NameError: name 'wiki_movies_df' is not defined

# %%
wiki_movies_df.count()
# Out:
# url                      7033
# year                     7033
# imdb_link                7033
# title                    7032
# Based on                 2181
# Starring                 6849
# Cinematography           6342
# Release date             7001
# Running time             6894
# Country                  6797
# Language                 6789
# Budget                   4738
# Box office               5485
# Director                 7033
# Distributor              6676
# Editor(s)                6485
# Composer(s)              6515
# Producer(s)              6831
# Production company(s)    5355
# Writer(s)                6834
# imdb_id                  7033
# dtype: int64

# %%
# pull out box office data to see formatting issues
box_office = wiki_movies_df['Box office'].dropna()
# check the length of the results - is this a reasonable ammount?
len(box_office)
# Out:
# 5485

# %%
# make sure box office data is a string (Regex only works on strings)
# def is_not_a_string(x):
#     return type(x) != str

# box_office[box_office.map(is_not_a_string)]

# Use a lambda function to write the above code:
box_office[box_office.map(lambda x: type(x) !=str)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
# Join the series of lists into a series of strings so we can perform regex
box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
# Write regex forms to match the most common box office data
# form 1 $123.4 million
form_one = r"\$\s*\d+\.?\d*\s*[mb]illion"

# count up how many box office values match form 1
box_office.str.contains(form_one, flags=re.IGNORECASE, na=False).sum()
# Out:
# 3901

# %%
# form 2 $123,456,789
form_two = r"\$\s*\d{1,3}(?:[,\.]\d{1,3})+(?!\s[mb]illi?on)"

# count up how many box office values match form 2
box_office.str.contains(form_two, flags=re.IGNORECASE, na=False).sum()
# Out:
# 1637

# %%
# make 2 boolean strings to find values that equal both forms

matches_form_one = box_office.str.contains(form_one, flags=re.IGNORECASE, na=False)
matches_form_two = box_office.str.contains(form_two, flags=re.IGNORECASE, na=False)

# use element-wise logical operator ~ to get the remaining box office values that don't match our forms
box_office[~matches_form_one & ~matches_form_two]
# Out:
# 600                      $5000 (US)
# 1070                     35,254,617
# 1480                     £3 million
# 1865                   ¥1.1 billion
# 2032                            N/A
# 2091                           $309
# 2665    926,423 admissions (France)
# 3088      $32 [2] –33.1 million [1]
# 3631                            TBA
# 3879       CN¥3.650 million (China)
# 4116                     £7,385,434
# 4306                         $20-30
# 4492                   $47.7 millon
# 5447                          £2.56
# 5784                       413 733$
# 6013                        Unknown
# 6369                          $111k
# 6370                           $588
# 6593                 less than $372
# 6843                        8 crore
# 6904                    $6.9 millon
# Name: Box office, dtype: object

# %%
# solve for box office values give in a range using replace()
box_office = box_office.str.replace(r"\$.*[-—–](?![a-z])", "$", regex=True)

box_office.str.extract(f"({form_one}|{form_two})")
# Out:
#                   0
# 0     $21.4 million
# 1      $2.7 million
# 2       $57,718,089
# 3        $7,331,647
# 4        $6,939,946
# ...             ...
# 7070  $19.4 million
# 7071  $41.9 million
# 7072  $76.1 million
# 7073  $38.4 million
# 7074   $5.5 million
#
# [5485 rows x 1 columns]

# %%
# create a function to turn these extracted box_office strings to numeric values. 
def parse_dollars(s):
    # If s is not a string, return NaN
    if type(s) != str:
        return np.nan
    
    # If input is of the form $###.# million
    if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.I):
    
        # remove dollar sign and " million"
        s = re.sub("\$|\s|[a-zA-Z]", "", s)
        
        # convert to float and multipy by a million
        value = float(s) * 10**6
    
        # return values
        return value

    
    # if input is of the form $###.# billion
    elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.I):
        
        # remove dollar sign and " billion"
        s = re.sub("\$|\s|[a-zA-Z]", "", s)
        
        # convert to float and multiply by a billion
        value = float(s) * 10**6
        
        # return value
        return value
    
    # If the input is of the form $###,###,###
    elif re.match(r'\$\d{1-3}(?:[,\.]\d{3})+(?!\s(mb)illion)', s, flags=re.I):
        
        # remove $ and commas
        s = re.sub("\$|,","", s)
        
        # convert to float
        value = float(s) * 10**6
        
        # return value
        return value
    
    # otherwise, return NaN
        else:
        return np.nan

# %%
# parse the box office values to numeric values.
# extract values from box_office using str. extract. Then we'll try parse_dollars

wiki_movies_df["box_office"] = box_office.str.extract(f"({form_one}|{form_two})", flags=re.I)[0].apply(parse_dollars)
# wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

wiki_movies_df["box_office"]
# Out:
# 0       21400000.0
# 1        2700000.0
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 7071    41900000.0
# 7072    76100000.0
# 7073    38400000.0
# 7074     5500000.0
# 7075           NaN
# Name: box_office, Length: 7033, dtype: float64

# %%
# drop the box office column
wiki_movies_df.drop('Box office', axis=1, inplace=True)

# %%
# Parse the budget data
# create a budget variable
budget = wiki_movies_df['Budget'].dropna()
budget
# Out:
# 0        $20 million
# 1         $6 million
# 2        $35 million
# 3        $12 million
# 4        $25 million
#             ...
# 7070    €4.3 million
# 7071     $42 million
# 7072     $60 million
# 7073     $20 million
# 7074      $9 million
# Name: Budget, Length: 4738, dtype: object

# %%
# convert lists to strings
budget = budget.map(lambda x: ' '.join(x) if type(x) == list else x)

# remove any values between a dollar sign and a hyphen (fix budgets in ranges)
budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# %%
# make 2 boolean strings to find values that equal both forms

matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE, na=False)
matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE, na=False)

# use element-wise logical operator ~ to get the remaining box office values that don't match our forms
budget[~matches_form_one & ~matches_form_two]
# Out:
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 973             $34 [3] [4] million
# 1126               $120 [4] million
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3360               $150 [6] million
# 3802                   £4.2 million
# 3906                            N/A
# 3959                    760,000 USD
# 4470                       19 crore
# 4641                    £17 million
# 5034              $$200 [4] million
# 5055           $155 [2] [3] million
# ...

# %%
# remove the citation numbers in brackets like [2]
budget = budget.str.replace(r'\[\d+\]\s*', ' ')
budget[~matches_form_one & ~matches_form_two]
# Out:
# C:\Users\ellye\AppData\Local\Temp/ipykernel_11864/3729591751.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   budget = budget.str.replace(r'\[\d+\]\s*', ' ')
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 973                   $34   million
# 1126                  $120  million
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3360                  $150  million
# 3802                   £4.2 million
# ...

# %%
# extract values from budget using str. extract. Then we'll try parse_dollars

wiki_movies_df["budget"] = budget.str.extract(f"({form_one}|{form_two})", flags=re.I)[0].apply(parse_dollars)

wiki_movies_df["budget"]
# Out:
# 0       20000000.0
# 1        6000000.0
# 2       35000000.0
# 3       12000000.0
# 4       25000000.0
#            ...
# 7071    42000000.0
# 7072    60000000.0
# 7073    20000000.0
# 7074     9000000.0
# 7075           NaN
# Name: budget, Length: 7033, dtype: float64

# %%
# drop the original budget column
wiki_movies_df.drop('Budget', axis=1, inplace=True)

# %%
# Parse the release date
# make a variable that holds the non-null values of release date in the DF, converting lists to strings
release_date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

date_form_one = r"(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]?\d,\s\d{4}"
date_form_two = r"\d{4}.[01]\d.[01234]\d"
date_form_three = r"(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}"
date_form_four = r"\d{4}"

# %%
# extract and read the dates with regex expression forms
release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})', flags=re.I)

# use the to_datetime() method in pandas to parse the dates
wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)
release_date
# Out:
# 0                            July 11, 1990 ( 1990-07-11 )
# 1       May 17, 1990 ( 1990-05-17 ) (Cannes Film Marke...
# 2                          August 10, 1990 ( 1990-08-10 )
# 3                        December 25, 1990 ( 1990-12-25 )
# 4                                       December 19, 1990
#                               ...
# 7071     December 25, 2018 ( 2018-12-25 ) (United States)
# 7072    December 11, 2018 ( 2018-12-11 ) ( Samuel Gold...
# 7073    November 8, 2018 ( 2018-11-08 ) ( AFI Fest ) D...
# 7074    August 31, 2018 ( 2018-08-31 ) ( Telluride ) D...
# 7075                      28 December 2018 ( 2018-12-28 )
# Name: Release date, Length: 7001, dtype: object

# %%
# create a variable for non-null values of release date in Dataframe
running_time = wiki_movies_df['Running time'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)
running_time
# Out:
# 0                                 102 minutes
# 1                                 114 minutes
# 2                                 113 minutes
# 3                                 106 minutes
# 4                                  95 minutes
#                         ...
# 7071                               90 minutes
# 7072                              132 minutes
# 7073                              120 minutes
# 7074                              123 minutes
# 7075    Variable; 90 minutes for default path
# Name: Running time, Length: 6894, dtype: object

# %%
# count the running times that look like "100 minutes"
running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False).sum()
# Out:
# 6877

# %%
# view the remaining run times that do not match the formula
running_time[running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False) != True]
# Out:
# 668                     UK:84 min (DVD version) US:86 min
# 727                         78-102 min (depending on cut)
# 840                       Varies (79 [3] –84 [1] minutes)
# 1347                                              25 : 03
# 1443    United States: 77 minutes Argentina: 94 minute...
# 1499                                            1hr 35min
# 1551                                               varies
# 1774                    Netherlands:96 min, Canada:95 min
# 1777                                       approx. 14 min
# 2273                                           1 h 43 min
# 2993                                               1h 48m
# 3925                                              4 hours
# 4425    US domestic version: 86 minutes Original versi...
# 4967    Theatrical cut: 97 minutes Unrated cut: 107 mi...
# 5424                    115 [1] /123 [2] /128 [3] minutes
# 5447                                    1 hour 32 minutes
# ...

# %%
running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')
running_time_extract
# Out:
#         0    1    2
# 0     NaN  NaN  102
# 1     NaN  NaN  114
# 2     NaN  NaN  113
# 3     NaN  NaN  106
# 4     NaN  NaN   95
# ...   ...  ...  ...
# 7071  NaN  NaN   90
# 7072  NaN  NaN  132
# 7073  NaN  NaN  120
# 7074  NaN  NaN  123
# 7075  NaN  NaN   90
#
# [6894 rows x 3 columns]

# %%
# change results to strings using the to_numeric() method, setting the errors agument to to "coerce"
# coercing the errors will turn the empty strings into NANs and then we can se fillna() to change them to 0s.

running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)
# running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors="coerce")).fillna(0)

# %%
# apply a function that will convert the hour capture groups and minute capture groups to minutes. 
# save output to wiki_movies_df.
wiki_movies_df['running_time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)
# wiki_movies_df['running_time'] = running_time_extract.apply[lambda row: row[0]*60 + row[1] if row[2], axis=1)

# %%
# drop running-time from the wiki_movies df
wiki_movies_df.drop('Running time', axis=1, inplace=True)
wiki_movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7071    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7072     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7073  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# ...

# %%
# print the dataframe to a csv for merging with the kaggle data.
wiki_movies_df.to_csv('wiki_movies.csv')
